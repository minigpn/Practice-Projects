# %%
import pandas as pd

# %%
data1 = pd.read_excel(r'D:\datasheet\DATASHEET EXCEL.xlsx')

# %%
data1
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN        NaN        NaN          NaN        NaN
# 1          NaN         NaN        NaN        NaN          NaN        NaN
# 2          NaN         NaN        NaN        NaN          NaN        NaN
# 3          NaN         NaN       year  PROJECT A          PV   PROJECT B
# 4          NaN         NaN          0      -5000          NaN      -5000
# 5          NaN         NaN          1       2500  2232.142857       2000
# 6          NaN         NaN          2       2000  1594.387755       2000
# 7          NaN         NaN          3       2800  1992.984694       4000
# 8          NaN         NaN        NaN        NaN          NaN        NaN
# 9          NaN         NaN        NaN        NaN  5819.515306        NaN
# 10         NaN         NaN        NaN        NaN          NaN        NaN
# 11         NaN         NaN        NPV        NaN   819.515306        NaN
# ...
